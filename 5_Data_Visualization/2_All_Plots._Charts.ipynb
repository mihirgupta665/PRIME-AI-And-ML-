# %% [markdown]
# # Plots and thier types
# ## plt.plot(X,Y) : Line Plot
# ## plt.bar(x,height) : Veritical bar graph (categories in x axis, values in y axis)
# ## plt.barh(y, width) : Horizontal bar chart (values in x axis, categiries in x axis)
# ## plt.scatter(x,y) : Scatter plot
# ## plt.pie(data) : pie chart
# ## plt.hist(data, bins) : Histogram
# ## plt.boxplot(data) - Box plot

# %% [markdown]
# # Attributes and Method for plots
# ## plt.text("x-axis value", "y-axis value" + numeric_gap, "text_to_print", alignment)
# - alignment :  ha="center"
# ## plt.xlim(lower, upper) : changes the limit for lower and upper for x axis
# ## plt.ylim(lower, upper) : changes the limit for lower and upper for y axis

# %%
import matplotlib.pyplot as plt

# %%
oscar_movies = ["Birdman", "Spotlight", "Moonlight", "The Shape of Water", "Green Book", 
                "Parasite", "Nomadland", "CODA", "Everything Everywhere All at Once", "Oppenheimer"]

years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]
oscar_revenues = [110, 115, 120, 125, 130, 135, 130, 137.1, 143.5, 146.6, 150]
plt.bar(years, oscar_revenues, color="yellow")
plt.title("Oscar Revenue per year")
plt.xlabel("years")
plt.ylabel("Revenue (in $M)")

for i in range(len(years)):
    plt.text(years[i], oscar_revenues[i]+3, str(oscar_revenues[i]), ha="center")  # print the text on top of the bar

plt.tight_layout()
plt.ylim(0, max(oscar_revenues)+20)
plt.xlim(min(years)-2, max(years)+2)
plt.show()

# %% [markdown]
# - default width of each graph is 0.8
# - width decrease to 0.4 to plot 2 and 0.27 to plot 3
# - and x-width/2, x+width/2 or x-width,x,x+width written in plot to have width

# %%
import numpy as np

years = [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

oscar_movies = ["Birdman", "Spotlight", "Moonlight", "The Shape of Water", "Green Book", "Parasite",
                "Nomadland", "CODA", "Everything Everywhere All at Once", "Oppenheimer"]
oscar_revenues = [103, 98, 65, 195, 321, 262, 39, 2, 141, 975]

non_oscar_movies = ["Mad Max: Fury Road", "The Revenant", "La La Land", "Dunkirk", "Bohemian Rhapsody",
                    "Joker", "Tenet", "Dune", "Top Gun: Maverick", "Avatar: The Way of Water"]
non_oscar_revenues = [375, 533, 448, 527, 910, 1074, 365, 402, 1496, 2320]


x = np.arange(len(years))
width = 0.4


plt.bar(x-width/2, oscar_revenues, width, label="Oscar Revenue")
plt.bar(x+width/2, non_oscar_revenues, width, label="Non-Oscar Revenue")
plt.legend()
plt.title("Oscar Revenue Vs Non-Oscar Revenue")
plt.tight_layout()
# plt.xlim(0-1, 10+1)
plt.show()

# %%
oscar_movies = ["Birdman", "Spotlight", "Moonlight", "The Shape of Water", "Green Book", "Parasite",
                "Nomadland", "CODA", "Everything Everywhere All at Once", "Oppenheimer"]
oscar_revenues = [103, 98, 65, 195, 321, 262, 39, 2, 141, 975]
plt.barh(oscar_movies, oscar_revenues)  # y-axis, x-axis unlike bar(X,Y)  barh is barh(Y,X)
plt.title("Movies  and thier revenue")
plt.xlabel("Revenue")
plt.ylabel("Movie Names")
# Out:
# Text(0, 0.5, 'Movie Names')

# %% [markdown]
# # Scatter Plots:  shows relationship between two variables by plotting points on a 2D plane
# ## plt.scatter(X,Y,color=name_color, s=numeric_size, marker="symbol", alpha=(0 to 1), cmap="default_gradient", c=Y)
# ## cmap are the values which defines that in the gradient of colore it has c paramter to define the range for that gradient (could be found on the mathplotlib page)
# ## plt.colorbar(label="label_name") : used to display the scale of cmap color (what doees the gradient-color represents), label tells
# ## plt.annotate("text", xy=(x_point, y_point), xytext=(x_text, y_text)) : display text for meaning of the point
# - xy : value of x and y to have text  and    xytext : location for the distance of text from the xy location

# %%
people = ["Person A", "Person B", "Person C", "Person D", "Person E", "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]
colors = ["red" if x>=135 else "green" for x in blood_pressure]
plt.scatter(age, blood_pressure, color=colors, s=blood_pressure, marker=">", alpha=0.3)
plt.title("Age VS Bp")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.tight_layout()

# %%
people = ["Person A", "Person B", "Person C", "Person D", "Person E", "Person F", "Person G", "Person H", "Person I", "Person J"]
age = [22, 25, 30, 35, 40, 45, 50, 55, 60, 65]
blood_pressure = [110, 115, 120, 122, 125, 130, 135, 123, 145, 150]
colors = ["red" if x>=135 else "green" for x in blood_pressure]
plt.scatter(age, blood_pressure, s=blood_pressure, marker=">", cmap="plasma", c=blood_pressure)
plt.title("Age VS Bp")
plt.xlabel("Age")
plt.ylabel("Blood Pressure")
plt.colorbar(label="Blood Pressure")
for i in range(len(people)):
    plt.annotate(people[i], xy=(age[i], blood_pressure[i]), xytext=(age[i]-3, blood_pressure[i]+2))
plt.tight_layout()
plt.xlim(min(age)-5, max(age)+5)
plt.ylim(min(blood_pressure)-5, max(blood_pressure)+5)
# Out:
# (105.0, 155.0)
