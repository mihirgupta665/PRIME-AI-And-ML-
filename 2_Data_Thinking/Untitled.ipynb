# %% [markdown]
# # Data Science
# ## Step involved
# - Define the Problem
# - Data Collection
# - Exploratory Data Analysis (EDA)
# - Data Cleaning And Pre-Processing
# - Feature Engineering
# - Modeling
# - Evaluation
# - Fine Tuning
# - Deployment
# - Maintainence
