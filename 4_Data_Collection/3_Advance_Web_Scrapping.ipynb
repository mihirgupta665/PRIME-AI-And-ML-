# %%
import requests
from bs4 import BeautifulSoup

# %%
page_count = 1

while True:
    URL = f"https://quotes.toscrape.com/page/{page_count}/"
    res = requests.get(URL)
    soup = BeautifulSoup(res.text, 'lxml')
    quotes = soup.select("div.quote")   # diffence need to get the obeservation whether page exists or not
    # print(quotes)
    if not quotes:
        print("No qoutes at this page",page_count)
        break

    with open(f"scrapped_data/quotes{page_count}.html", "w", encoding="utf-8") as f:    # to write html text encoding="utf-8" need to be passed as p
        # print(res)
        f.write(res.text)
        print("Downloaded data from page",page_count)
        
    page_count+=1
# Out:
# Downloaded data from page 1
# Downloaded data from page 2
# Downloaded data from page 3
# Downloaded data from page 4
# Downloaded data from page 5
# Downloaded data from page 6
# Downloaded data from page 7
# Downloaded data from page 8
# Downloaded data from page 9
# Downloaded data from page 10
# No qoutes at this page 11

# %%
with open("scrapped_data/quotes1.html", "r", encoding="utf-8") as f:
    html_content=f.read()
    # print(html_content)
soup = BeautifulSoup(html_content, "lxml")

# %%
all_quotes = soup.select("div.quote")
# print(all_quotes)
all_quotes_value = []
life_quotes = []
for q in all_quotes :
    all_tags = q.select(".tags .tag")
    # print(all_tags)
    temp = []
    for tag in all_tags:
        temp.append(tag.get_text())
    # print(temp)
    if "life" in temp:
        text = q.select_one("span.text").get_text()
        author = q.select_one("small.author").get_text()
        # print(text)
        # print(author)
        life_quotes.append([text, author])
    all_quotes_value.append(temp)
    
# print(all_quotes_value)
print(life_quotes)
# Out:
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# [['“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”', 'Albert Einstein'], ['“It is better to be hated for what you are than to be loved for what you are not.”', 'André Gide']]

# %%
import pandas as pd
df = pd.DataFrame(life_quotes, columns=["Quote", "Author"])
df
# Out:
#                                                Quote           Author
# 0  “There are only two ways to live your life. On...  Albert Einstein
# 1  “It is better to be hated for what you are tha...       André Gide
