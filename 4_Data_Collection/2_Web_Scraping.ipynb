# %% [markdown]
# ## WebSRaping Websites : toscrape.com, scrapethissite.com

# %% [markdown]
# # Response
# ## res.status_code() : it is used to get the status code of response
# ## res.content() : to take out the raw byte of the website
# ## res.raise_for_status()  : Raises errors for 4XX/5XX responses
# ## except requests.exceptions.RequestException as e: print("Error : ",e)
# this is the way to handle the error of requests
# - time.sleep() : tp add delays to automated request to avoid getting blocked due to crossing of rate of hitting the server
# - header = { "User-Agent": "Mozilla/5.0" }

# %%
import requests

# %%
URL = "https://www.scrapethissite.com/pages/simple/"
res = requests.get(URL)
res
# Out:
# <Response [200]>

# %%
if res.status_code==200:
    print(res.headers);
# Out:
# {'Date': 'Tue, 20 Jan 2026 05:51:35 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Nel': '{"report_to":"heroku-nel","response_headers":["Via"],"max_age":3600,"success_fraction":0.01,"failure_fraction":0.1}', 'Report-To': '{"group":"heroku-nel","endpoints":[{"url":"https://nel.heroku.com/reports?s=82sP1wex1x%2Bw48tRhx7zU%2By4P51jquc0chRkYegcVns%3D\\u0026sid=67ff5de4-ad2b-4112-9289-cf96be89efed\\u0026ts=1768888294"}],"max_age":3600}', 'Reporting-Endpoints': 'heroku-nel="https://nel.heroku.com/reports?s=82sP1wex1x%2Bw48tRhx7zU%2By4P51jquc0chRkYegcVns%3D&sid=67ff5de4-ad2b-4112-9289-cf96be89efed&ts=1768888294"', 'Server': 'cloudflare', 'Via': '1.1 heroku-router', 'cf-cache-status': 'DYNAMIC', 'Content-Encoding': 'zstd', 'CF-RAY': '9c0c4d02bfa5c68f-MRS', 'alt-svc': 'h3=":443"; ma=86400'}

# %%
with open("scrapped_data/data1.html", "w", encoding="utf-8") as f:
    f.write(res.text)
