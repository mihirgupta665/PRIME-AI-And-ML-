# %%
# !pip install gymnasium
# !pip install "gymnasium[toy-text]"

# %%
import gymnasium as gym
import numpy as np
import random

# %%
env = gym.make("CliffWalking-v1")   # creating the environment
env
# Out:
# <OrderEnforcing<PassiveEnvChecker<CliffWalkingEnv<CliffWalking-v1>>>>

# %%
print(f"Observation State :  {env.observation_space.n} ")  # total number of states
print(f"Action State : {env.action_space.n} ")   # total number of saction space
# Out:
# Observation State :  48
# Action State : 4

# %%
starting_state, _ = env.reset()
print(f"Starting State : {starting_state}")   #3*12 + 0
# Out:
# Starting State : 36

# %% [markdown]
# # SARSA

# %%
gamma = 0.99
alpha = 0.5
epsilon = 0.1
episodes = 600

# %%
# Q table
Q = np.zeros((48,4))   # total state = 48

# %%
# Policy
def epsilon_greedy(state):
    if (random.random() < epsilon):
        return env.action_space.sample()  # explore
    else:
        return np.argmax(Q[state])  # exploit

# %%
for episode in range(episodes):

    env = gym.make("CliffWalking-v1")     # env mode creation

    done = False      # check if terminated or truncated
    total_reward = 0
    episode_len = 0

    state, _ = env.reset()   # gives 2 values state and some information
    # print(env.reser())
    action = epsilon_greedy(state)  # on policy SARSA decides the action on basis of policy

    while not done:    # till done = True

        next_state, reward, terminated, truncated, _ = env.step(action)  # gives 5 parameters

        done = truncated or terminated
        next_action = epsilon_greedy(next_state)  # on policy so action is decided by policy

        # SARSA updation of Q values of Q tables
        Q[state, action] = Q[state, action] + (alpha * (reward + gamma * (Q[next_state, next_action] - Q[state, action])))

        total_reward += reward   # reward cumulating
        episode_len += 1

        # reached to new state so state changed and action changed
        state = next_state   
        action = next_action


    print(f"episode : {episode+1} has total length = {episode_len} reward = {total_reward}")
    env.close()  # close that episodes environment
# Out:
# episode : 1 has total length = 565 reward = -2050
# episode : 2 has total length = 61 reward = -61
# episode : 3 has total length = 98 reward = -98
# episode : 4 has total length = 49 reward = -49
# episode : 5 has total length = 88 reward = -88
# episode : 6 has total length = 61 reward = -61
# episode : 7 has total length = 76 reward = -76
# episode : 8 has total length = 98 reward = -98
# episode : 9 has total length = 49 reward = -49
# episode : 10 has total length = 93 reward = -93
# episode : 11 has total length = 59 reward = -158
# episode : 12 has total length = 63 reward = -63
# episode : 13 has total length = 49 reward = -49
# episode : 14 has total length = 55 reward = -55
# episode : 15 has total length = 49 reward = -49
# episode : 16 has total length = 82 reward = -280
# episode : 17 has total length = 31 reward = -130
# episode : 18 has total length = 50 reward = -50
# episode : 19 has total length = 31 reward = -229
# episode : 20 has total length = 49 reward = -49
# episode : 21 has total length = 33 reward = -33
# episode : 22 has total length = 39 reward = -39
# episode : 23 has total length = 29 reward = -29
# episode : 24 has total length = 43 reward = -43
# episode : 25 has total length = 30 reward = -30
# episode : 26 has total length = 46 reward = -46
# episode : 27 has total length = 67 reward = -67
# episode : 28 has total length = 32 reward = -32
# episode : 29 has total length = 43 reward = -43
# episode : 30 has total length = 28 reward = -28
# episode : 31 has total length = 37 reward = -37
# episode : 32 has total length = 71 reward = -170
# episode : 33 has total length = 27 reward = -27
# episode : 34 has total length = 38 reward = -38
# episode : 35 has total length = 28 reward = -28
# episode : 36 has total length = 37 reward = -37
# episode : 37 has total length = 55 reward = -154
# episode : 38 has total length = 35 reward = -35
# episode : 39 has total length = 31 reward = -31
# episode : 40 has total length = 20 reward = -20
# episode : 41 has total length = 27 reward = -27
# episode : 42 has total length = 26 reward = -26
# episode : 43 has total length = 19 reward = -19
# episode : 44 has total length = 21 reward = -21
# episode : 45 has total length = 33 reward = -132
# episode : 46 has total length = 27 reward = -27
# episode : 47 has total length = 19 reward = -19
# episode : 48 has total length = 23 reward = -23
# episode : 49 has total length = 48 reward = -147
# episode : 50 has total length = 26 reward = -26
# episode : 51 has total length = 68 reward = -167
# episode : 52 has total length = 30 reward = -30
# episode : 53 has total length = 22 reward = -22
# episode : 54 has total length = 23 reward = -23
# episode : 55 has total length = 17 reward = -17
# episode : 56 has total length = 23 reward = -23
# episode : 57 has total length = 19 reward = -19
# episode : 58 has total length = 25 reward = -25
# episode : 59 has total length = 19 reward = -19
# episode : 60 has total length = 37 reward = -37
# episode : 61 has total length = 22 reward = -22
# episode : 62 has total length = 28 reward = -28
# episode : 63 has total length = 28 reward = -28
# episode : 64 has total length = 25 reward = -25
# episode : 65 has total length = 25 reward = -25
# episode : 66 has total length = 18 reward = -18
# episode : 67 has total length = 29 reward = -29
# episode : 68 has total length = 25 reward = -25
# episode : 69 has total length = 25 reward = -25
# episode : 70 has total length = 31 reward = -130
# episode : 71 has total length = 42 reward = -141
# episode : 72 has total length = 52 reward = -151
# episode : 73 has total length = 36 reward = -36
# episode : 74 has total length = 25 reward = -25
# episode : 75 has total length = 23 reward = -23
# episode : 76 has total length = 19 reward = -19
# episode : 77 has total length = 20 reward = -20
# episode : 78 has total length = 21 reward = -21
# episode : 79 has total length = 17 reward = -17
# episode : 80 has total length = 23 reward = -23
# episode : 81 has total length = 31 reward = -31
# episode : 82 has total length = 19 reward = -19
# episode : 83 has total length = 24 reward = -24
# episode : 84 has total length = 27 reward = -27
# episode : 85 has total length = 19 reward = -19
# episode : 86 has total length = 18 reward = -18
# episode : 87 has total length = 19 reward = -19
# episode : 88 has total length = 23 reward = -23
# episode : 89 has total length = 17 reward = -17
# episode : 90 has total length = 19 reward = -19
# episode : 91 has total length = 31 reward = -31
# episode : 92 has total length = 19 reward = -19
# episode : 93 has total length = 20 reward = -20
# episode : 94 has total length = 21 reward = -21
# episode : 95 has total length = 17 reward = -17
# episode : 96 has total length = 18 reward = -18
# episode : 97 has total length = 25 reward = -25
# episode : 98 has total length = 17 reward = -17
# episode : 99 has total length = 20 reward = -20
# episode : 100 has total length = 24 reward = -24
# episode : 101 has total length = 24 reward = -24
# episode : 102 has total length = 23 reward = -23
# episode : 103 has total length = 50 reward = -248
# episode : 104 has total length = 21 reward = -21
# episode : 105 has total length = 27 reward = -126
# episode : 106 has total length = 21 reward = -21
# episode : 107 has total length = 21 reward = -21
# episode : 108 has total length = 19 reward = -19
# episode : 109 has total length = 28 reward = -127
# episode : 110 has total length = 17 reward = -17
# episode : 111 has total length = 17 reward = -17
# episode : 112 has total length = 19 reward = -19
# episode : 113 has total length = 17 reward = -17
# episode : 114 has total length = 22 reward = -22
# episode : 115 has total length = 25 reward = -25
# episode : 116 has total length = 26 reward = -26
# episode : 117 has total length = 19 reward = -19
# episode : 118 has total length = 19 reward = -19
# episode : 119 has total length = 33 reward = -33
# episode : 120 has total length = 29 reward = -29
# episode : 121 has total length = 17 reward = -17
# episode : 122 has total length = 21 reward = -21
# episode : 123 has total length = 18 reward = -18
# episode : 124 has total length = 23 reward = -23
# episode : 125 has total length = 23 reward = -23
# episode : 126 has total length = 18 reward = -18
# episode : 127 has total length = 18 reward = -18
# episode : 128 has total length = 18 reward = -18
# episode : 129 has total length = 18 reward = -18
# episode : 130 has total length = 20 reward = -20
# episode : 131 has total length = 17 reward = -17
# episode : 132 has total length = 21 reward = -21
# episode : 133 has total length = 30 reward = -30
# episode : 134 has total length = 19 reward = -19
# episode : 135 has total length = 19 reward = -19
# episode : 136 has total length = 21 reward = -21
# episode : 137 has total length = 17 reward = -17
# episode : 138 has total length = 17 reward = -17
# episode : 139 has total length = 25 reward = -25
# episode : 140 has total length = 17 reward = -17
# episode : 141 has total length = 20 reward = -20
# episode : 142 has total length = 20 reward = -20
# episode : 143 has total length = 21 reward = -21
# episode : 144 has total length = 29 reward = -29
# episode : 145 has total length = 18 reward = -18
# episode : 146 has total length = 19 reward = -19
# episode : 147 has total length = 21 reward = -21
# episode : 148 has total length = 17 reward = -17
# episode : 149 has total length = 19 reward = -19
# episode : 150 has total length = 19 reward = -19
# episode : 151 has total length = 19 reward = -19
# episode : 152 has total length = 21 reward = -21
# episode : 153 has total length = 21 reward = -21
# episode : 154 has total length = 20 reward = -20
# episode : 155 has total length = 17 reward = -17
# episode : 156 has total length = 19 reward = -19
# episode : 157 has total length = 19 reward = -19
# episode : 158 has total length = 48 reward = -147
# episode : 159 has total length = 20 reward = -20
# episode : 160 has total length = 28 reward = -28
# episode : 161 has total length = 17 reward = -17
# episode : 162 has total length = 22 reward = -22
# episode : 163 has total length = 17 reward = -17
# episode : 164 has total length = 29 reward = -29
# episode : 165 has total length = 17 reward = -17
# episode : 166 has total length = 18 reward = -18
# episode : 167 has total length = 17 reward = -17
# episode : 168 has total length = 18 reward = -18
# episode : 169 has total length = 21 reward = -21
# episode : 170 has total length = 20 reward = -20
# episode : 171 has total length = 18 reward = -18
# episode : 172 has total length = 18 reward = -18
# episode : 173 has total length = 19 reward = -19
# episode : 174 has total length = 17 reward = -17
# episode : 175 has total length = 26 reward = -26
# episode : 176 has total length = 27 reward = -27
# episode : 177 has total length = 18 reward = -18
# episode : 178 has total length = 27 reward = -27
# episode : 179 has total length = 33 reward = -33
# episode : 180 has total length = 25 reward = -25
# episode : 181 has total length = 23 reward = -23
# episode : 182 has total length = 21 reward = -21
# episode : 183 has total length = 25 reward = -25
# episode : 184 has total length = 28 reward = -28
# episode : 185 has total length = 28 reward = -28
# episode : 186 has total length = 24 reward = -24
# episode : 187 has total length = 31 reward = -31
# episode : 188 has total length = 22 reward = -22
# episode : 189 has total length = 26 reward = -125
# episode : 190 has total length = 43 reward = -43
# episode : 191 has total length = 22 reward = -22
# episode : 192 has total length = 24 reward = -24
# episode : 193 has total length = 24 reward = -24
# episode : 194 has total length = 25 reward = -25
# episode : 195 has total length = 21 reward = -21
# episode : 196 has total length = 23 reward = -23
# episode : 197 has total length = 30 reward = -129
# episode : 198 has total length = 24 reward = -24
# episode : 199 has total length = 23 reward = -23
# episode : 200 has total length = 21 reward = -21
# episode : 201 has total length = 21 reward = -21
# episode : 202 has total length = 23 reward = -23
# episode : 203 has total length = 18 reward = -18
# episode : 204 has total length = 24 reward = -24
# episode : 205 has total length = 17 reward = -17
# episode : 206 has total length = 19 reward = -19
# episode : 207 has total length = 17 reward = -17
# episode : 208 has total length = 18 reward = -18
# episode : 209 has total length = 19 reward = -19
# episode : 210 has total length = 17 reward = -17
# episode : 211 has total length = 19 reward = -19
# episode : 212 has total length = 22 reward = -22
# episode : 213 has total length = 21 reward = -21
# episode : 214 has total length = 17 reward = -17
# episode : 215 has total length = 20 reward = -20
# episode : 216 has total length = 19 reward = -19
# episode : 217 has total length = 19 reward = -19
# episode : 218 has total length = 18 reward = -117
# episode : 219 has total length = 21 reward = -21
# episode : 220 has total length = 17 reward = -17
# episode : 221 has total length = 19 reward = -19
# episode : 222 has total length = 18 reward = -18
# episode : 223 has total length = 17 reward = -17
# episode : 224 has total length = 19 reward = -19
# episode : 225 has total length = 18 reward = -18
# episode : 226 has total length = 17 reward = -17
# episode : 227 has total length = 19 reward = -19
# episode : 228 has total length = 19 reward = -19
# episode : 229 has total length = 21 reward = -21
# episode : 230 has total length = 21 reward = -21
# episode : 231 has total length = 25 reward = -25
# episode : 232 has total length = 20 reward = -20
# episode : 233 has total length = 17 reward = -17
# episode : 234 has total length = 17 reward = -17
# episode : 235 has total length = 17 reward = -17
# episode : 236 has total length = 17 reward = -17
# episode : 237 has total length = 20 reward = -20
# episode : 238 has total length = 24 reward = -24
# episode : 239 has total length = 24 reward = -123
# episode : 240 has total length = 18 reward = -18
# episode : 241 has total length = 21 reward = -21
# episode : 242 has total length = 17 reward = -17
# episode : 243 has total length = 17 reward = -17
# episode : 244 has total length = 19 reward = -19
# episode : 245 has total length = 19 reward = -19
# episode : 246 has total length = 43 reward = -142
# episode : 247 has total length = 17 reward = -17
# episode : 248 has total length = 19 reward = -19
# episode : 249 has total length = 23 reward = -23
# episode : 250 has total length = 18 reward = -18
# episode : 251 has total length = 18 reward = -18
# episode : 252 has total length = 20 reward = -20
# episode : 253 has total length = 19 reward = -19
# episode : 254 has total length = 18 reward = -18
# episode : 255 has total length = 17 reward = -17
# episode : 256 has total length = 17 reward = -17
# episode : 257 has total length = 17 reward = -17
# episode : 258 has total length = 24 reward = -24
# episode : 259 has total length = 17 reward = -17
# episode : 260 has total length = 18 reward = -18
# episode : 261 has total length = 18 reward = -18
# episode : 262 has total length = 19 reward = -19
# episode : 263 has total length = 21 reward = -21
# episode : 264 has total length = 17 reward = -17
# episode : 265 has total length = 17 reward = -17
# episode : 266 has total length = 17 reward = -17
# episode : 267 has total length = 18 reward = -18
# episode : 268 has total length = 19 reward = -19
# episode : 269 has total length = 23 reward = -23
# episode : 270 has total length = 18 reward = -18
# episode : 271 has total length = 17 reward = -17
# episode : 272 has total length = 17 reward = -17
# episode : 273 has total length = 17 reward = -17
# episode : 274 has total length = 21 reward = -21
# episode : 275 has total length = 21 reward = -21
# episode : 276 has total length = 92 reward = -92
# episode : 277 has total length = 17 reward = -17
# episode : 278 has total length = 25 reward = -25
# episode : 279 has total length = 19 reward = -19
# episode : 280 has total length = 21 reward = -21
# episode : 281 has total length = 21 reward = -21
# episode : 282 has total length = 24 reward = -24
# episode : 283 has total length = 40 reward = -139
# episode : 284 has total length = 19 reward = -19
# episode : 285 has total length = 25 reward = -25
# episode : 286 has total length = 19 reward = -19
# episode : 287 has total length = 22 reward = -22
# episode : 288 has total length = 22 reward = -22
# episode : 289 has total length = 18 reward = -18
# episode : 290 has total length = 20 reward = -20
# episode : 291 has total length = 18 reward = -18
# episode : 292 has total length = 17 reward = -17
# episode : 293 has total length = 28 reward = -28
# episode : 294 has total length = 17 reward = -17
# episode : 295 has total length = 21 reward = -21
# episode : 296 has total length = 19 reward = -19
# episode : 297 has total length = 19 reward = -19
# episode : 298 has total length = 17 reward = -17
# episode : 299 has total length = 17 reward = -17
# episode : 300 has total length = 21 reward = -21
# episode : 301 has total length = 19 reward = -19
# episode : 302 has total length = 21 reward = -21
# episode : 303 has total length = 20 reward = -20
# episode : 304 has total length = 19 reward = -19
# episode : 305 has total length = 26 reward = -26
# episode : 306 has total length = 21 reward = -21
# episode : 307 has total length = 21 reward = -21
# episode : 308 has total length = 17 reward = -17
# episode : 309 has total length = 17 reward = -17
# episode : 310 has total length = 19 reward = -19
# episode : 311 has total length = 18 reward = -18
# episode : 312 has total length = 17 reward = -17
# episode : 313 has total length = 19 reward = -19
# episode : 314 has total length = 19 reward = -19
# episode : 315 has total length = 91 reward = -91
# episode : 316 has total length = 85 reward = -85
# episode : 317 has total length = 56 reward = -56
# episode : 318 has total length = 54 reward = -54
# episode : 319 has total length = 25 reward = -25
# episode : 320 has total length = 29 reward = -29
# episode : 321 has total length = 42 reward = -42
# episode : 322 has total length = 30 reward = -30
# episode : 323 has total length = 32 reward = -32
# episode : 324 has total length = 35 reward = -35
# episode : 325 has total length = 37 reward = -37
# episode : 326 has total length = 26 reward = -26
# episode : 327 has total length = 25 reward = -25
# episode : 328 has total length = 46 reward = -145
# episode : 329 has total length = 27 reward = -27
# episode : 330 has total length = 36 reward = -36
# episode : 331 has total length = 18 reward = -18
# episode : 332 has total length = 23 reward = -23
# episode : 333 has total length = 19 reward = -19
# episode : 334 has total length = 21 reward = -21
# episode : 335 has total length = 18 reward = -18
# episode : 336 has total length = 25 reward = -25
# episode : 337 has total length = 25 reward = -25
# episode : 338 has total length = 24 reward = -24
# episode : 339 has total length = 24 reward = -24
# episode : 340 has total length = 19 reward = -19
# episode : 341 has total length = 19 reward = -19
# episode : 342 has total length = 17 reward = -17
# episode : 343 has total length = 27 reward = -27
# episode : 344 has total length = 18 reward = -18
# episode : 345 has total length = 21 reward = -21
# episode : 346 has total length = 19 reward = -19
# episode : 347 has total length = 25 reward = -25
# episode : 348 has total length = 24 reward = -24
# episode : 349 has total length = 17 reward = -17
# episode : 350 has total length = 18 reward = -18
# episode : 351 has total length = 17 reward = -17
# episode : 352 has total length = 20 reward = -20
# episode : 353 has total length = 20 reward = -20
# episode : 354 has total length = 17 reward = -17
# episode : 355 has total length = 19 reward = -19
# episode : 356 has total length = 17 reward = -17
# episode : 357 has total length = 18 reward = -18
# episode : 358 has total length = 21 reward = -21
# episode : 359 has total length = 22 reward = -22
# episode : 360 has total length = 17 reward = -17
# episode : 361 has total length = 17 reward = -17
# episode : 362 has total length = 24 reward = -123
# episode : 363 has total length = 19 reward = -19
# episode : 364 has total length = 20 reward = -20
# episode : 365 has total length = 26 reward = -125
# episode : 366 has total length = 28 reward = -28
# episode : 367 has total length = 22 reward = -22
# episode : 368 has total length = 20 reward = -20
# episode : 369 has total length = 20 reward = -20
# episode : 370 has total length = 17 reward = -17
# episode : 371 has total length = 19 reward = -19
# episode : 372 has total length = 17 reward = -17
# episode : 373 has total length = 19 reward = -19
# episode : 374 has total length = 20 reward = -20
# episode : 375 has total length = 19 reward = -19
# episode : 376 has total length = 17 reward = -17
# episode : 377 has total length = 24 reward = -24
# episode : 378 has total length = 25 reward = -25
# episode : 379 has total length = 21 reward = -21
# episode : 380 has total length = 28 reward = -28
# episode : 381 has total length = 24 reward = -123
# episode : 382 has total length = 18 reward = -18
# episode : 383 has total length = 19 reward = -19
# episode : 384 has total length = 23 reward = -23
# episode : 385 has total length = 18 reward = -18
# episode : 386 has total length = 18 reward = -18
# episode : 387 has total length = 21 reward = -21
# episode : 388 has total length = 18 reward = -18
# episode : 389 has total length = 20 reward = -20
# episode : 390 has total length = 23 reward = -23
# episode : 391 has total length = 24 reward = -24
# episode : 392 has total length = 17 reward = -17
# episode : 393 has total length = 30 reward = -30
# episode : 394 has total length = 19 reward = -19
# episode : 395 has total length = 18 reward = -18
# episode : 396 has total length = 17 reward = -17
# episode : 397 has total length = 25 reward = -25
# episode : 398 has total length = 17 reward = -17
# episode : 399 has total length = 17 reward = -17
# episode : 400 has total length = 25 reward = -25
# episode : 401 has total length = 19 reward = -19
# episode : 402 has total length = 17 reward = -17
# episode : 403 has total length = 17 reward = -17
# episode : 404 has total length = 18 reward = -18
# episode : 405 has total length = 19 reward = -19
# episode : 406 has total length = 18 reward = -18
# episode : 407 has total length = 19 reward = -19
# episode : 408 has total length = 17 reward = -17
# episode : 409 has total length = 21 reward = -21
# episode : 410 has total length = 19 reward = -19
# episode : 411 has total length = 22 reward = -22
# episode : 412 has total length = 19 reward = -19
# episode : 413 has total length = 18 reward = -18
# episode : 414 has total length = 17 reward = -17
# episode : 415 has total length = 17 reward = -17
# episode : 416 has total length = 29 reward = -29
# episode : 417 has total length = 19 reward = -19
# episode : 418 has total length = 88 reward = -88
# episode : 419 has total length = 262 reward = -361
# episode : 420 has total length = 138 reward = -237
# episode : 421 has total length = 30 reward = -30
# episode : 422 has total length = 57 reward = -57
# episode : 423 has total length = 39 reward = -138
# episode : 424 has total length = 56 reward = -56
# episode : 425 has total length = 29 reward = -29
# episode : 426 has total length = 40 reward = -40
# episode : 427 has total length = 41 reward = -41
# episode : 428 has total length = 40 reward = -139
# episode : 429 has total length = 42 reward = -42
# episode : 430 has total length = 29 reward = -29
# episode : 431 has total length = 23 reward = -23
# episode : 432 has total length = 47 reward = -47
# episode : 433 has total length = 37 reward = -37
# episode : 434 has total length = 22 reward = -121
# episode : 435 has total length = 50 reward = -149
# episode : 436 has total length = 20 reward = -20
# episode : 437 has total length = 33 reward = -33
# episode : 438 has total length = 56 reward = -56
# episode : 439 has total length = 19 reward = -19
# episode : 440 has total length = 27 reward = -27
# episode : 441 has total length = 27 reward = -27
# episode : 442 has total length = 19 reward = -19
# episode : 443 has total length = 26 reward = -26
# episode : 444 has total length = 23 reward = -23
# episode : 445 has total length = 47 reward = -146
# episode : 446 has total length = 81 reward = -180
# episode : 447 has total length = 36 reward = -135
# episode : 448 has total length = 24 reward = -123
# episode : 449 has total length = 17 reward = -17
# episode : 450 has total length = 21 reward = -21
# episode : 451 has total length = 18 reward = -18
# episode : 452 has total length = 26 reward = -26
# episode : 453 has total length = 23 reward = -23
# episode : 454 has total length = 23 reward = -23
# episode : 455 has total length = 21 reward = -21
# episode : 456 has total length = 17 reward = -17
# episode : 457 has total length = 21 reward = -21
# episode : 458 has total length = 17 reward = -17
# episode : 459 has total length = 17 reward = -17
# episode : 460 has total length = 21 reward = -21
# episode : 461 has total length = 20 reward = -20
# episode : 462 has total length = 19 reward = -19
# episode : 463 has total length = 19 reward = -19
# episode : 464 has total length = 21 reward = -21
# episode : 465 has total length = 21 reward = -21
# episode : 466 has total length = 23 reward = -23
# episode : 467 has total length = 17 reward = -17
# episode : 468 has total length = 17 reward = -17
# episode : 469 has total length = 19 reward = -19
# episode : 470 has total length = 17 reward = -17
# episode : 471 has total length = 17 reward = -17
# episode : 472 has total length = 17 reward = -17
# episode : 473 has total length = 19 reward = -19
# episode : 474 has total length = 23 reward = -122
# episode : 475 has total length = 23 reward = -23
# episode : 476 has total length = 17 reward = -17
# episode : 477 has total length = 19 reward = -19
# episode : 478 has total length = 18 reward = -18
# episode : 479 has total length = 17 reward = -17
# episode : 480 has total length = 17 reward = -17
# episode : 481 has total length = 17 reward = -17
# episode : 482 has total length = 17 reward = -17
# episode : 483 has total length = 18 reward = -18
# episode : 484 has total length = 21 reward = -21
# episode : 485 has total length = 21 reward = -21
# episode : 486 has total length = 21 reward = -21
# episode : 487 has total length = 58 reward = -58
# episode : 488 has total length = 229 reward = -229
# episode : 489 has total length = 21 reward = -21
# episode : 490 has total length = 47 reward = -47
# episode : 491 has total length = 57 reward = -57
# episode : 492 has total length = 43 reward = -43
# episode : 493 has total length = 86 reward = -185
# episode : 494 has total length = 48 reward = -48
# episode : 495 has total length = 27 reward = -27
# episode : 496 has total length = 22 reward = -121
# episode : 497 has total length = 53 reward = -53
# episode : 498 has total length = 31 reward = -130
# episode : 499 has total length = 38 reward = -38
# episode : 500 has total length = 28 reward = -28
# episode : 501 has total length = 21 reward = -21
# episode : 502 has total length = 17 reward = -17
# episode : 503 has total length = 24 reward = -24
# episode : 504 has total length = 23 reward = -23
# episode : 505 has total length = 27 reward = -27
# episode : 506 has total length = 19 reward = -19
# episode : 507 has total length = 22 reward = -22
# episode : 508 has total length = 17 reward = -17
# episode : 509 has total length = 21 reward = -120
# episode : 510 has total length = 23 reward = -23
# episode : 511 has total length = 21 reward = -21
# episode : 512 has total length = 21 reward = -21
# episode : 513 has total length = 17 reward = -17
# episode : 514 has total length = 19 reward = -19
# episode : 515 has total length = 19 reward = -19
# episode : 516 has total length = 20 reward = -20
# episode : 517 has total length = 17 reward = -17
# episode : 518 has total length = 18 reward = -18
# episode : 519 has total length = 22 reward = -22
# episode : 520 has total length = 18 reward = -18
# episode : 521 has total length = 17 reward = -17
# episode : 522 has total length = 19 reward = -19
# episode : 523 has total length = 21 reward = -21
# episode : 524 has total length = 19 reward = -19
# episode : 525 has total length = 17 reward = -17
# episode : 526 has total length = 19 reward = -19
# episode : 527 has total length = 18 reward = -18
# episode : 528 has total length = 18 reward = -18
# episode : 529 has total length = 19 reward = -19
# episode : 530 has total length = 18 reward = -18
# episode : 531 has total length = 17 reward = -17
# episode : 532 has total length = 19 reward = -19
# episode : 533 has total length = 17 reward = -17
# episode : 534 has total length = 26 reward = -26
# episode : 535 has total length = 20 reward = -20
# episode : 536 has total length = 19 reward = -19
# episode : 537 has total length = 18 reward = -18
# episode : 538 has total length = 17 reward = -17
# episode : 539 has total length = 20 reward = -20
# episode : 540 has total length = 17 reward = -17
# episode : 541 has total length = 18 reward = -18
# episode : 542 has total length = 19 reward = -19
# episode : 543 has total length = 18 reward = -18
# episode : 544 has total length = 19 reward = -19
# episode : 545 has total length = 19 reward = -19
# episode : 546 has total length = 21 reward = -21
# episode : 547 has total length = 19 reward = -19
# episode : 548 has total length = 18 reward = -18
# episode : 549 has total length = 23 reward = -23
# episode : 550 has total length = 20 reward = -20
# episode : 551 has total length = 17 reward = -17
# episode : 552 has total length = 17 reward = -17
# episode : 553 has total length = 24 reward = -24
# episode : 554 has total length = 24 reward = -24
# episode : 555 has total length = 27 reward = -27
# episode : 556 has total length = 18 reward = -18
# episode : 557 has total length = 19 reward = -19
# episode : 558 has total length = 19 reward = -19
# episode : 559 has total length = 21 reward = -21
# episode : 560 has total length = 26 reward = -26
# episode : 561 has total length = 19 reward = -19
# episode : 562 has total length = 18 reward = -18
# episode : 563 has total length = 19 reward = -19
# episode : 564 has total length = 20 reward = -20
# episode : 565 has total length = 17 reward = -17
# episode : 566 has total length = 17 reward = -17
# episode : 567 has total length = 17 reward = -17
# episode : 568 has total length = 26 reward = -26
# episode : 569 has total length = 21 reward = -21
# episode : 570 has total length = 17 reward = -17
# episode : 571 has total length = 21 reward = -21
# episode : 572 has total length = 28 reward = -28
# episode : 573 has total length = 21 reward = -21
# episode : 574 has total length = 22 reward = -22
# episode : 575 has total length = 23 reward = -23
# episode : 576 has total length = 19 reward = -19
# episode : 577 has total length = 17 reward = -17
# episode : 578 has total length = 17 reward = -17
# episode : 579 has total length = 17 reward = -17
# episode : 580 has total length = 17 reward = -17
# episode : 581 has total length = 18 reward = -18
# episode : 582 has total length = 21 reward = -21
# episode : 583 has total length = 17 reward = -17
# episode : 584 has total length = 20 reward = -20
# episode : 585 has total length = 17 reward = -17
# episode : 586 has total length = 20 reward = -20
# episode : 587 has total length = 18 reward = -18
# episode : 588 has total length = 19 reward = -19
# episode : 589 has total length = 30 reward = -30
# episode : 590 has total length = 19 reward = -19
# episode : 591 has total length = 21 reward = -21
# episode : 592 has total length = 23 reward = -23
# episode : 593 has total length = 19 reward = -19
# episode : 594 has total length = 17 reward = -17
# episode : 595 has total length = 20 reward = -20
# episode : 596 has total length = 23 reward = -23
# episode : 597 has total length = 17 reward = -17
# episode : 598 has total length = 22 reward = -22
# episode : 599 has total length = 43 reward = -43
# episode : 600 has total length = 29 reward = -29
