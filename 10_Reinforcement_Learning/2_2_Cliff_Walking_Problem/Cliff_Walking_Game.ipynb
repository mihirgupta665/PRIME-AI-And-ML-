# %%
# !pip install gymnasium
# !pip install "gymnasium[toy-text]"
# Out:
# Collecting gymnasium
#   Downloading gymnasium-1.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in c:\programdata\anaconda3\envs\dl_env\lib\site-packages (from gymnasium) (2.2.6)
# Collecting cloudpickle>=1.2.0 (from gymnasium)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\programdata\anaconda3\envs\dl_env\lib\site-packages (from gymnasium) (4.15.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading farama_notifications-0.0.6-py3-none-any.whl.metadata (729 bytes)
# Downloading gymnasium-1.3.0-py3-none-any.whl (953 kB)
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    -------------------------------- ------- 786.4/953.9 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 953.9/953.9 kB 2.9 MB/s  0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Downloading farama_notifications-0.0.6-py3-none-any.whl (2.9 kB)
# Installing collected packages: farama-notifications, cloudpickle, gymnasium
#
#    -------------------------- ------------- 2/3 [gymnasium]
#    -------------------------- ------------- 2/3 [gymnasium]
#    -------------------------- ------------- 2/3 [gymnasium]
#    ---------------------------------------- 3/3 [gymnasium]
#
# Successfully installed cloudpickle-3.1.2 farama-notifications-0.0.6 gymnasium-1.3.0

# %%
import gymnasium as gym
import numpy as np
import random

# %%
env = gym.make("CliffWalking-v1")   # creating the environment
env
# Out:
# <OrderEnforcing<PassiveEnvChecker<CliffWalkingEnv<CliffWalking-v1>>>>

# %%
print(f"Observation State :  {env.observation_space.n} ")  # total number of states
print(f"Action State : {env.action_space.n} ")   # total number of saction space
# Out:
# Observation State :  48
# Action State : 4

# %%
starting_state, _ = env.reset()
print(f"Starting State : {starting_state}")   #3*12 + 0
# Out:
# Starting State : 36
