# %%
# !pip install gymnasium
# !pip install "gymnasium[toy-text]"
# Out:
# ...
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/953.9 kB ? eta -:--:--
#    -------------------------------- ------- 786.4/953.9 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 953.9/953.9 kB 2.9 MB/s  0:00:00
# ...
#
#    -------------------------- ------------- 2/3 [gymnasium]
#    -------------------------- ------------- 2/3 [gymnasium]
#    -------------------------- ------------- 2/3 [gymnasium]
#    ---------------------------------------- 3/3 [gymnasium]
#
# ...

# %%
import gymnasium as gym
import numpy as np
import random
