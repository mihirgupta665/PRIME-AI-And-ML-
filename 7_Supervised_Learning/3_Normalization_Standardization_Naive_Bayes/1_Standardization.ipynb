# %% [markdown]
# ## Normalization
# Xscaled = (X - Xmin) / (Xmax - Xmin)
# ## Standardization
# Xstandardization = (x - u)/s
#
# ### scaler.fit() : evaluate u and s values
# ### scaler.transform() : uses the u and s value to transform the data
# ### scaler.fit_transform() : evalute u and s and also uses those values to transform the data

# %% [markdown]
# # Naive Bayes Theorem
# - P(yes/ x1,x2,x3) ~=  P(x1/yes).P(x2/yes).p(x3/yes).p(yes) / (p(x1).p(x2).p(x3))
