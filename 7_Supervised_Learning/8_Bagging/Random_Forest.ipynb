# %% [markdown]
# # Ensemble Learning
# ## Bagging : It uses modified replicated of a training data set to train multiple base learners, gen. with the same training algorithm
# ## Boosting : Each Model sequentially tries to correct mistakes of the previous one.
# ### Out Of Bag : Its a built-in validation method in bagging that lets us estimate model performance without a separate validation set
