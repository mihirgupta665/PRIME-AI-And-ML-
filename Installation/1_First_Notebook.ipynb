# %% [markdown]
# # First Notebook
# ## Its JuypterLab Magic
# - Hi i am Mihir Gutpa
# - I am doing Machine Learning
# - Jupyter lab makes works so easy and readable

# %%
print("Yippee!! I am using jupyter notebook")
# Out:
# Yippee!! I am usign jupyter notebook
